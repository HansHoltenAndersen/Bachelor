# %%
import pandas as pd

# Load Excel
df = pd.read_excel("Hjemsendelse 16-11-2025.xlsx", sheet_name="Ordnet")

# Convert to LaTeX
latex_table = df.to_latex(index=False)

# Save to file
with open("Main_table.tex", "w") as f:
    f.write(latex_table)
